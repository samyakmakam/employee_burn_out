# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'F:\Desktop\train.csv')

# %%
df.head()
# Out:
#                 Employee_ID Date_of_Joining  Gender  Company  WFH  \
# 0  fffe32003000360033003200      30-09-2008  Female  Service   No
# 1      fffe3700360033003500      30-11-2008    Male  Service  Yes
# 2  fffe31003300320037003900      10-03-2008  Female  Product  Yes
# 3  fffe32003400380032003900      03-11-2008    Male  Service  Yes
# 4  fffe31003900340031003600      24-07-2008  Female  Service   No
#
#    Designation  Resource  Mental_Fatigue_Score  Burn_Rate
# 0            2       3.0                   3.8       0.16
# 1            1       2.0                   5.0       0.36
# 2            2       NaN                   5.8       0.49
# 3            1       1.0                   2.6       0.20
# 4            3       7.0                   6.9       0.52

# %%
df['Gender']
# Out:
# 0        Female
# 1          Male
# 2        Female
# 3          Male
# 4        Female
#           ...
# 22745    Female
# 22746    Female
# 22747      Male
# 22748    Female
# 22749      Male
# Name: Gender, Length: 22750, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22750 entries, 0 to 22749
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee_ID           22750 non-null  object
#  1   Date_of_Joining       22750 non-null  object
#  2   Gender                22750 non-null  object
#  3   Company               22750 non-null  object
#  4   WFH                   22750 non-null  object
#  5   Designation           22750 non-null  int64
#  6   Resource              21369 non-null  float64
#  7   Mental_Fatigue_Score  20633 non-null  float64
#  8   Burn_Rate             21626 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 1.6+ MB

# %%
df=df.dropna(axis=0)

# %%
(df['Employee_ID'].unique()).shape
# Out:
# (18590,)

# %%
df.shape
# Out:
# (18590, 9)

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
df['Gender']=label_encoder.fit_transform(df['Gender'])

# %%
df
# Out:
#                     Employee_ID Date_of_Joining  Gender  Company  WFH  \
# 0      fffe32003000360033003200      30-09-2008       0  Service   No
# 1          fffe3700360033003500      30-11-2008       1  Service  Yes
# 3      fffe32003400380032003900      03-11-2008       1  Service  Yes
# 4      fffe31003900340031003600      24-07-2008       0  Service   No
# 5          fffe3300350037003500      26-11-2008       1  Product  Yes
# ...                         ...             ...     ...      ...  ...
# 22743      fffe3300390030003600      15-12-2008       0  Product  Yes
# 22744  fffe32003500370033003200      27-05-2008       1  Product   No
# 22746  fffe33003000350031003800      19-01-2008       0  Product  Yes
# 22748  fffe33003300320036003900      10-01-2008       0  Service   No
# 22749      fffe3400350031003800      06-01-2008       1  Product   No
#
#        Designation  Resource  Mental_Fatigue_Score  Burn_Rate
# 0                2       3.0                   3.8       0.16
# ...

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Date_of_Joining', 'Gender', 'Company', 'WFH',
#        'Designation', 'Resource', 'Mental_Fatigue_Score', 'Burn_Rate'],
#       dtype='object')

# %%
df['Company']=label_encoder.fit_transform(df['Company'])
df['WFH']=label_encoder.fit_transform(df['WFH'])

# %%
df=df.drop(['Employee_ID'],axis=1)

# %%
df
# Out:
#       Date_of_Joining  Gender  Company  WFH  Designation  Resource  \
# 0          30-09-2008       0        1    0            2       3.0
# 1          30-11-2008       1        1    1            1       2.0
# 3          03-11-2008       1        1    1            1       1.0
# 4          24-07-2008       0        1    0            3       7.0
# 5          26-11-2008       1        0    1            2       4.0
# ...               ...     ...      ...  ...          ...       ...
# 22743      15-12-2008       0        0    1            1       3.0
# 22744      27-05-2008       1        0    0            3       7.0
# 22746      19-01-2008       0        0    1            3       6.0
# 22748      10-01-2008       0        1    0            2       5.0
# 22749      06-01-2008       1        0    0            3       6.0
#
#        Mental_Fatigue_Score  Burn_Rate
# 0                       3.8       0.16
# 1                       5.0       0.36
# 3                       2.6       0.20
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
(df['Burn_Rate']>1).unique()
# Out:
# array([False])

# %%
df.describe()
# Out:
#              Gender       Company           WFH   Designation      Resource  \
# count  18590.000000  18590.000000  18590.000000  18590.000000  18590.000000
# mean       0.475686      0.654868      0.539537      2.179398      4.486552
# std        0.499422      0.475424      0.498448      1.133148      2.044848
# min        0.000000      0.000000      0.000000      0.000000      1.000000
# 25%        0.000000      0.000000      0.000000      1.000000      3.000000
# 50%        0.000000      1.000000      1.000000      2.000000      4.000000
# 75%        1.000000      1.000000      1.000000      3.000000      6.000000
# max        1.000000      1.000000      1.000000      5.000000     10.000000
#
#        Mental_Fatigue_Score     Burn_Rate
# count          18590.000000  18590.000000
# mean               5.732173      0.452444
# std                1.920547      0.197848
# min                0.000000      0.000000
# 25%                4.600000      0.320000
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df.Mental_Fatigue_Score)
# Out:
# D:\ProgramData\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Mental_Fatigue_Score', ylabel='Density'>

# %%
sns.distplot(df.Burn_Rate)
# Out:
# D:\ProgramData\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Burn_Rate', ylabel='Density'>

# %%
from sklearn.model_selection import train_test_split
x=df[[ 'Gender', 'Company', 'WFH', 'Designation',
       'Resource', 'Mental_Fatigue_Score']]

# %%
x
# Out:
#        Gender  Company  WFH  Designation  Resource  Mental_Fatigue_Score
# 0           0        1    0            2       3.0                   3.8
# 1           1        1    1            1       2.0                   5.0
# 3           1        1    1            1       1.0                   2.6
# 4           0        1    0            3       7.0                   6.9
# 5           1        0    1            2       4.0                   3.6
# ...       ...      ...  ...          ...       ...                   ...
# 22743       0        0    1            1       3.0                   6.0
# 22744       1        0    0            3       7.0                   6.2
# 22746       0        0    1            3       6.0                   6.7
# 22748       0        1    0            2       5.0                   5.9
# 22749       1        0    0            3       6.0                   7.8
#
# [18590 rows x 6 columns]

# %%
y=df['Burn_Rate']

# %%
y
# Out:
# 0        0.16
# 1        0.36
# 3        0.20
# 4        0.52
# 5        0.29
#          ...
# 22743    0.48
# 22744    0.54
# 22746    0.59
# 22748    0.52
# 22749    0.61
# Name: Burn_Rate, Length: 18590, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0)

# %%
x_train.shape
# Out:
# (13942, 6)

# %%
y_train.shape
# Out:
# (13942,)

# %%
from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
model = ExtraTreesRegressor()
model.fit(x,y)
# Out:
# ExtraTreesRegressor()

# %%
model.feature_importances_
# Out:
# array([0.00394918, 0.00368012, 0.00654313, 0.08889953, 0.28329112,
#        0.61363692])

# %%
f_impo=pd.Series(model.feature_importances_,index=x.columns)
f_impo.nlargest().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor()

# %%
regressor.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
regressor.score(x_train,y_train)
# Out:
# 0.9522576001783248

# %%
regressor.score(x_test,y_test)
# Out:
# 0.9121225962710826

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.9213002411038812

# %%
lr.score(x_test,y_test)
# Out:
# 0.9186506933888854

# %%
pred=lr.predict(x_test)

# %%
import pickle as pkl
file=open('linr_reg.pkl','wb')
pkl.dump(lr,file)

# %%
sns.lineplot(y_test,pred)
# Out:
# D:\ProgramData\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Burn_Rate'>
